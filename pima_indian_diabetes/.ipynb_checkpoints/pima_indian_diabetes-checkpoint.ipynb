# %% [markdown]
# ## Dataset on predicting the chances of person getting diagnoised with daibetes based on the features

# %%
import pandas as pd
import numpy as np

# %%
# #loading data using python load csv module
# import csv
# filename = 'diabetes.csv'
# raw_data = open(filename, 'rb')
# reader = csv.reader(raw_data, delimiter=',', quoting=csv.QUOTE_NONE)
# x = list(reader)
# data = np.array(x).astype('float')
# print(data)

# %%
filename = 'diabetes.csv'
df = pd.read_csv(filename)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# 12            10      139             80              0        0  27.1
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# 15             7      100              0              0        0  30.0
# 16             0      118             84             47      230  45.8
# 17             7      107             74              0        0  29.6
# 18             1      103             30             38       83  43.3
# 19             1      115             70             30       96  34.6
# 20             3      126             88             41      235  39.3
# 21             8       99             84              0        0  35.4
# 22             7      196             90              0        0  39.8
# 23             9      119             80             35        0  29.0
# 24            11      143             94             33      146  36.6
# 25            10      125             70             26      115  31.1
# 26             7      147             76              0        0  39.4
# 27             1       97             66             15      140  23.2
# 28            13      145             82             19      110  22.2
# 29             5      117             92              0        0  34.1
# ..           ...      ...            ...            ...      ...   ...
# 738            2       99             60             17      160  36.6
# 739            1      102             74              0        0  39.5
# 740           11      120             80             37      150  42.3
# 741            3      102             44             20       94  30.8
# 742            1      109             58             18      116  28.5
# 743            9      140             94              0        0  32.7
# 744           13      153             88             37      140  40.6
# 745           12      100             84             33      105  30.0
# 746            1      147             94             41        0  49.3
# 747            1       81             74             41       57  46.3
# 748            3      187             70             22      200  36.4
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# 751            1      121             78             39       74  39.0
# 752            3      108             62             24        0  26.0
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 756            7      137             90             41        0  32.0
# 757            0      123             72              0        0  36.3
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# 5                       0.201   30        0
# 6                       0.248   26        1
# 7                       0.134   29        0
# 8                       0.158   53        1
# 9                       0.232   54        1
# 10                      0.191   30        0
# 11                      0.537   34        1
# 12                      1.441   57        0
# 13                      0.398   59        1
# 14                      0.587   51        1
# 15                      0.484   32        1
# 16                      0.551   31        1
# 17                      0.254   31        1
# 18                      0.183   33        0
# 19                      0.529   32        1
# 20                      0.704   27        0
# 21                      0.388   50        0
# 22                      0.451   41        1
# 23                      0.263   29        1
# 24                      0.254   51        1
# 25                      0.205   41        1
# 26                      0.257   43        1
# 27                      0.487   22        0
# 28                      0.245   57        0
# 29                      0.337   38        0
# ..                        ...  ...      ...
# 738                     0.453   21        0
# 739                     0.293   42        1
# 740                     0.785   48        1
# 741                     0.400   26        0
# 742                     0.219   22        0
# 743                     0.734   45        1
# 744                     1.174   39        0
# 745                     0.488   46        0
# 746                     0.358   27        1
# 747                     1.096   32        0
# 748                     0.408   36        1
# 749                     0.178   50        1
# 750                     1.182   22        1
# 751                     0.261   28        0
# 752                     0.223   25        0
# 753                     0.222   26        1
# 754                     0.443   45        1
# 755                     1.057   37        1
# 756                     0.391   39        0
# 757                     0.258   52        1
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# 761                     0.403   43        1
# 762                     0.142   33        0
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.shape
# Out:
# (768, 9)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
### Knowing the data type of each feature 
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
### Lets print the float64 datatype attribute names
for index in df.dtypes.index:
    if df.dtypes.loc[index] == 'float64':
        print(index)
# Out:
# BMI
# DiabetesPedigreeFunction

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# **It has only numerical data and no categorical data**

# %%
df.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# 12           10      139             80              0        0  27.1
# 13            1      189             60             23      846  30.1
# 14            5      166             72             19      175  25.8
# 15            7      100              0              0        0  30.0
# 16            0      118             84             47      230  45.8
# 17            7      107             74              0        0  29.6
# 18            1      103             30             38       83  43.3
# 19            1      115             70             30       96  34.6
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.627   50        1
# 1                      0.351   31        0
# 2                      0.672   32        1
# 3                      0.167   21        0
# 4                      2.288   33        1
# 5                      0.201   30        0
# 6                      0.248   26        1
# 7                      0.134   29        0
# 8                      0.158   53        1
# 9                      0.232   54        1
# 10                     0.191   30        0
# 11                     0.537   34        1
# 12                     1.441   57        0
# 13                     0.398   59        1
# 14                     0.587   51        1
# 15                     0.484   32        1
# 16                     0.551   31        1
# 17                     0.254   31        1
# 18                     0.183   33        0
# 19                     0.529   32        1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(df['BMI'], df['Outcome'])
plt.xlabel('BMI values')
plt.ylabel('Outcome with 1 or 0')
plt.title('Outcome based on BMI values')
# Out:
# Text(0.5, 1.0, 'Outcome based on BMI values')

# %%
plt.scatter(df['BMI'], df['SkinThickness'])

# %%
### In classification problems it is important to know the count of each class(i.e. the outcome class)
### highly imbalanced class distributed data is not preferred as it may not learn the features properly and can have a bias.
print(df['Outcome'].value_counts())

## Or using groupby 
print("\nUsing groupby: \n",df.groupby('Outcome').size())
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64
#
# Using groupby:
#  Outcome
# 0    500
# 1    268
# dtype: int64

# %% [markdown]
# # Knowing the corelation between the attributes.
# ### Some machine learning algorithms like linear and logistic regression can suffer poor performance if there are highly correlated attributes in your dataset.

# %%
### We will use here 'pearson' corelation method
correlation = df.corr(method = 'pearson')
print(correlation)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
### knowing the skewness of each feature distribution(this is referred to distribution that is assumesd to be gaussian(normal distribution))
print(df.skew())
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
for col in df.columns[:-1]:
    plt.hist(df[col])
    plt.xlabel(col+" values")
    plt.ylabel("count of values in each bin")
    plt.title("frequency distribution of "+col)
    plt.show()

# %% [markdown]
# ## Questions to explore:
# - **How does correlation between feartures affect model and why it is not desired to have a high correlation between features?**
# Ans: 'Multicolinearity', The prediction of the model (often denoted as y-hat) can still be accurate when multicollinearity is present among the predictor variables. However, the estimate of the coefficients for those correlated predictors is not likely to be meaningful.It will make the estimate highly in-stable. This instability will increase the variance of estimates. It means that if there is a small change in X, produces large changes in estimate.
#
# - **How skewness in features affect the model?**
# Ans : One reason could be that skewness could lead to biased predictions. That is high bias

# %% [markdown]
# ## visualising data, Univariate plots(visualising the trend of a single variable)

# %%
#plotting histogram 
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E27B3CE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E27E2FA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E27E59048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E27E7E588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E27EA7B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E27ED80B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E27F00630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E27F28BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E27F28C18>]],
#       dtype=object)

# %%
### Density plot, better visual substitute for histogram as considers density distribution and not in bins frequency
### When dealing with subplots it is best to have sharex to be False, which means all plots do not share same x-scale values.
df.plot(kind='density', subplots=True, layout=(3,3), sharex=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E275F40B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E276672B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2768B7F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E276B1D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E276E3320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2770B898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E27734E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E27765400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E27765438>]],
#       dtype=object)

# %%
### Plotting box plot to visualize the distribution around central tendencies. Also to look at the potential outliers
df.plot(kind= 'box', subplots = True, layout = (3,3),sharex = False, sharey = False)
# Out:
# Pregnancies                    AxesSubplot(0.125,0.657941;0.227941x0.222059)
# Glucose                     AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# BloodPressure               AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# SkinThickness                  AxesSubplot(0.125,0.391471;0.227941x0.222059)
# Insulin                     AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# BMI                         AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# DiabetesPedigreeFunction          AxesSubplot(0.125,0.125;0.227941x0.222059)
# Age                            AxesSubplot(0.398529,0.125;0.227941x0.222059)
# Outcome                        AxesSubplot(0.672059,0.125;0.227941x0.222059)
# dtype: object

# %% [markdown]
# ## Multivariate plots, visualising the trend between the multiple variable in a dataset

# %%
### Correlation matrix represented using a heat map
correlations = df.corr()
#plot correlation matrix
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin = -1, vmax = 1)
fig.colorbar(cax)
ticks = np.arange(0,9, 1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
names = df.columns
ax.set_xticklabels(names)
ax.set_yticklabels(names)
plt.show()

# %%
### Scatter plot matrix
from pandas.plotting import scatter_matrix
scatter_matrix(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2973FE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E297EC2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2971EBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2969DE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29563F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E282D35C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E281F39B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2814AE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2814AB70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29738C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2968CF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E296927B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2961ED30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E281AB2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E298C5860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E281EADD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E281DA390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E28431908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E28319E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2858F438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2816C9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2976DF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E284FD4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E282B2A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2956CFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E28251438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E28280B00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2970A0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E283B7630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E296D2BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E284BE160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E295B8080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E295BBC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E283D7208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29644780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29622CF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E282222B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E28522828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E28458668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E28456358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E283018D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E298EEE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2991D400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29946978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2996EEF0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E2999E4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E299C6A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E299EFF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29A21550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29A48AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29A7B080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29AA25F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29AC7B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29AFA128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29B216A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29B48C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29B7C1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29BA3748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29BCACC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29BFB278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29C247F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29C4BD68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29C7D320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29CA4898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29CCDE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29CFD3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29D25940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29D4EEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29D7F470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29DA69E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29DD0F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29E01518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29E27A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29E59048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29E7E5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29EA9B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29EDA0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29F02668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29F29BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29F5A198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E29F82710>]],
#       dtype=object)
